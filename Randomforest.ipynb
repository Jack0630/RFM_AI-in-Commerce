# %%
import numpy as np     # scientific calculation
import pandas as pd    # handle csv file
import seaborn as sns  # visualize 
import matplotlib.pyplot as plt # plotting

# %%
df =pd.read_csv('RFM_clear.csv')

# %%
df=df.rename(columns={'R_Quartile':'R','F_Quartile':'F','M_Quartile':'M'})

# %%
df['RFM_Score'] = df.R.astype(str)+ df.F.astype(str) + df.M.astype(str)
df.drop(df.tail(1).index,inplace=True)
df
# Out:
#       Unnamed: 0  CustomerID InvoiceDate   4 PURPLE FLOCK DINNER CANDLES  \
# 0              0     12347.0   2011/12/7                               0
# 1              1     12348.0   2011/9/25                               0
# 2              2     12349.0  2011/11/21                               0
# 3              3     12350.0    2011/2/2                               0
# 4              4     12352.0   2011/11/3                               0
# ...          ...         ...         ...                             ...
# 4364        4364     18277.0  2011/10/12                               0
# 4365        4365     18278.0   2011/9/27                               0
# 4366        4366     18280.0    2011/3/7                               0
# 4367        4367     18281.0   2011/6/12                               0
# 4368        4368     18282.0   2011/12/2                               0
#
#        50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# ...

# %%
from sklearn.model_selection import train_test_split
X = df.drop(labels=['InvoiceDate','R','F','M','RFM_Score'],axis=1).values
Y = df['RFM_Score'].values
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=160)

print('train shape:', X_train.shape)
print('test shape:', X_test.shape)
# Out:
# train shape: (3495, 3902)
# test shape: (874, 3902)

# %%
Y_test = Y_test.astype(int)

# %%
from sklearn.ensemble import RandomForestRegressor

#10個決策樹
rf = RandomForestRegressor(n_estimators= 10, random_state=42)
rf.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=42)

# %%
predictions = rf.predict(X_test)
predictions=np.around(predictions)

# %%
predictions=predictions.astype(int)

# %%
i=0
k=0

for n in range(len(predictions)):
    if predictions[n] == Y_test[n]:
        i+=1
    k+=1
    
rate= (i/k)*100
rate=str(round(rate,2))

print('precise rate : '+ rate + "%")
# Out:
# precise rate : 98.05%

# %% [markdown]
# # Only give recency

# %%
from sklearn.model_selection import train_test_split
X = df.drop(labels=['InvoiceDate','All','frequency','monetary','R','F','M','RFM_Score'],axis=1).values
Y = df['RFM_Score'].values
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=160)

Y_test = Y_test.astype(int)

from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators= 10, random_state=42)
rf.fit(X_train, Y_train)

predictions = rf.predict(X_test)
predictions=np.around(predictions)
predictions=predictions.astype(int)

i=0
k=0

for n in range(len(predictions)):
    if predictions[n] == Y_test[n]:
        i+=1
    k+=1
    
rate= (i/k)*100
rate=str(round(rate,2))

print('precise rate : '+ rate + "%")
# Out:
# precise rate : 3.55%

# %% [markdown]
# # Give recency, frequency

# %%
from sklearn.model_selection import train_test_split
X = df.drop(labels=['InvoiceDate','All','monetary','R','F','M','RFM_Score'],axis=1).values
Y = df['RFM_Score'].values
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=160)

Y_test = Y_test.astype(int)

from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators= 10, random_state=42)
rf.fit(X_train, Y_train)

predictions = rf.predict(X_test)
predictions=np.around(predictions)
predictions=predictions.astype(int)

i=0
k=0

for n in range(len(predictions)):
    if predictions[n] == Y_test[n]:
        i+=1
    k+=1
    
rate= (i/k)*100
rate=str(round(rate,2))

print('precise rate : '+ rate + "%")
# Out:
# precise rate : 47.25%

# %% [markdown]
# # Give recency, frequency, monetary

# %%
from sklearn.model_selection import train_test_split
X = df.drop(labels=['InvoiceDate','All','R','F','M','RFM_Score'],axis=1).values
Y = df['RFM_Score'].values
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=160)

Y_test = Y_test.astype(int)

from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators= 10, random_state=42)
rf.fit(X_train, Y_train)

predictions = rf.predict(X_test)
predictions=np.around(predictions)
predictions=predictions.astype(int)

i=0
k=0

for n in range(len(predictions)):
    if predictions[n] == Y_test[n]:
        i+=1
    k+=1
    
rate= (i/k)*100
rate=str(round(rate,2))

print('precise rate : '+ rate + "%")
# Out:
# precise rate : 98.28%
